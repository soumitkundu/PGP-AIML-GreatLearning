# %% [markdown]
# # Applied Statistics Project

# %%
# Including required libraries
import numpy as np    # library used for working with arrays.
import pandas as pd    # library used for data manipulation and analysis
import matplotlib.pyplot as plt    # library for plots and visualisations
import seaborn as sns    # library for visualisations
# %matplotlib inline 

import scipy.stats as stats

# %% [markdown]
# # Part A

# %% [markdown]
# ### 1. Please refer the table below to answer below questions:
#
# | Planned to purchase Product A | Actually placed order for Product A - Yes | Actually placed order for Product A - No | Total |
# | ----------- | ----------- | ----------- | ----------- |
# | **Yes** | 400 | 100 | 500 |
# | **No** | 200 | 1300 | 1500 |
# | **Total** | 600 | 1400 | 2000 |

# %% [markdown]
# >    A. Refer above table and find the joint probability of the people who planned to purchase and actually placed an order.

# %% [markdown]
# ### Ans:
# We can observe that out of 2000 people 400 people planed to purchase and actually placed an order.

# %%
orders = 400
people = 2000
probablity = (orders / people)
print('Joint probability of the people who planned to purchase and actually placed an order is', probablity)
# Out:
# Joint probability of the people who planned to purchase and actually placed an order is 0.2

# %% [markdown]
# >    B. Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that
# people planned to purchase.

# %% [markdown]
# ### Ans:
# A = Probablity of people actually purchased = 400 / 2000
#
# B = Probablity of people planned to purchase = 500 / 2000

# %%
P = (400/2000)/(500/2000)
print("Probability of the people who planned to purchase and actually placed an order, given that people planned to purchase is", P)
# Out:
# Probability of the people who planned to purchase and actually placed an order, given that people planned to purchase is 0.8

# %% [markdown]
# ### 2. An electrical manufacturing company conducts quality checks at specified periods on the products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random sample of 10 manufactured items is selected. Answer the following questions.

# %%
# Variable declaration
n = 10    # number of items in a sample
p = 0.05    # failure rate

k = np.arange(0,11)    # possible numbers of defective items

# using the binomial probability mass function(pmf) we can generate the probability distribution for each possible cases
binomial_pmf = stats.binom.pmf(k=k, n=n, p=p)

# using cumulative probability function(cdf) we can generate upto a certain range of distribution
binomial_cdf = stats.binom.cdf(k=k, n=n, p=p)

# %% [markdown]
# >    A. Probability that none of the items are defective?

# %% [markdown]
# ### Ans:
# Using the binomial function pmf we have generated the probability distribution for each possible cases in the variable binomial_pmf

# %%
print("Probability that none of the items are defective is %1.4f" %binomial_pmf[0])
# Out:
# Probability that none of the items are defective is 0.5987

# %% [markdown]
# >    B. Probability that exactly one of the items is defective?

# %% [markdown]
# ### Ans:
# In the same variable binomial_pmf we already calculated the probability distribution for exactly one item

# %%
print("Probability that exactly one of the items is defective is %1.4f" %binomial_pmf[1])
# Out:
# Probability that exactly one of the items is defective is 0.3151

# %% [markdown]
# >    C. Probability that two or fewer of the items are defective?

# %% [markdown]
# ### Ans:
# Using the binomial function cdf we have generated the cumulative probability for upto each possible cases in the variable binomial_cdf

# %%
print("Probability that two or fewer of the items are defective is %1.4f" %binomial_cdf[2])
# Out:
# Probability that two or fewer of the items are defective is 0.9885

# %% [markdown]
# >    D. Probability that three or more of the items are defective?

# %% [markdown]
# ### Ans:
# To findout three or more items defective we can simply substract the value of cumulative distribution of two from 1.

# %%
print("Probability that three or more of the items are defective is %1.4f" %(1 - binomial_cdf[2]))
# Out:
# Probability that three or more of the items are defective is 0.0115

# %% [markdown]
# ### 3. A car salesman sells on an average 3 cars per week.

# %% [markdown]
# - **Using Poisson law we can calculate the probablity.**

# %%
rate = 3    # Average sales per week
n = np.arange(0,20)    # asuming that in a given week the salesman can sell as many as 19 (this number can be anything)

poisson_cdf = stats.poisson.cdf(n, rate)

# %% [markdown]
# >    A. What is Probability that in a given week he will sell some cars?

# %% [markdown]
# ### Ans:

# %%
print("Probability that in a given week he will sell some cars is %1.4f" %(1 - poisson_cdf[0]))
# Out:
# Probability that in a given week he will sell some cars is 0.9502

# %% [markdown]
# >    B. What is Probability that in a given week he will sell 2 or more but less than 5 cars?

# %% [markdown]
# ### Ans:

# %%
print("Probability that in a given week he will sell 2 or more but less than 5 cars is %1.4f" %(poisson_cdf[4] - poisson_cdf[1]))
# Out:
# Probability that in a given week he will sell 2 or more but less than 5 cars is 0.6161

# %% [markdown]
# >    C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week.

# %% [markdown]
# ### Ans:

# %%
plt.plot(n,poisson_cdf, 'o-')
plt.title('Poisson distribution for cumulative probability')
plt.xlabel('Number of Cars sold per-week')
plt.ylabel('Cumulative probability of Cars sold per week')
plt.show()

# %% [markdown]
# ### 4. Accuracy in understanding orders for a speech based bot at a restaurant is important for the Company X which has designed, marketed and launched the product for a contactless delivery due to the COVID-19 pandemic. Recognition accuracy that measures the percentage of orders that are taken correctly is 86.8%. Suppose that you place an order with the bot and two friends of yours independently place orders with the same bot. Answer the following questions.

# %%
# Variable declaration
n = 3    # number of orders
p = 0.868    # success rate

k = np.arange(0,4)    # possible numbers of successful orders

# using the binomial pmf function we can generate the probability distribution for each possible cases
binomial_pmf = stats.binom.pmf(k=k, n=n, p=p)

# using binomial cdf function we can generate the cumulative distribution of upto a certain range
binomial_cdf = stats.binom.cdf(k=k, n=n, p=p)

# %% [markdown]
# >    A. What is the probability that all three orders will be recognised correctly?

# %% [markdown]
# ### Ans:

# %% [markdown]
# Using binomial probability mass function we have calculated the distribution of each possible cases.

# %%
print('The probability that all three orders will be recognised correctly is %1.4f' %binomial_pmf[3])
# Out:
# The probability that all three orders will be recognised correctly is 0.6540

# %% [markdown]
# >    B. What is the probability that none of the three orders will be recognised correctly?

# %% [markdown]
# ### Ans:

# %% [markdown]
# Using the same pmf function we already calculated the possible rate that none will be correct

# %%
print('The probability that none of the three orders will be recognised correctly is %1.4f' %binomial_pmf[0])
# Out:
# The probability that none of the three orders will be recognised correctly is 0.0023

# %% [markdown]
# > C. What is the probability that at least two of the three orders will be recognised correctly?

# %% [markdown]
# ### Ans:

# %% [markdown]
# Using the binomial cdf function we have generated the cumulative probability for upto each possible cases. Now to calculate at least two success case we need to find out 1 - probability of upto 1 failure case.

# %%
print('The probability that at least two of the three orders will be recognised correctly is %1.4f' %(1 - binomial_cdf[1]))
# Out:
# The probability that at least two of the three orders will be recognised correctly is 0.9523

# %% [markdown]
# ### 5. Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of Applied Statistics to get data driven business solution.

# %% [markdown]
# ### Ans:
# We can apply different statistical rules in various business solutions. Like improving the productivity of a manufacturing company or to predict the performance of a sales team or there can be so many example.
#
# Like using various applied statistics methods we can predict whether it will be profitable for a real estate company to construct a new complex at a given place. How the construction process and selling price will be so that it will be profitable.

# %% [markdown]
# # Part B

# %% [markdown]
# - **DOMAIN:** Sports
# - **CONTEXT:** Company X manages the men's top professional basketball division of the American league system. The dataset contains information on all the teams that have participated in all the past tournaments. It has data about how many baskets each team scored, conceded, how many times they came within the first 2 positions, how many tournaments they have qualified, their best position in the past, etc.
# - **DATA DESCRIPTION:** Basketball.csv - The data set contains information on all the teams so far participated in all the past tournaments.
# - **DATA DICTIONARY:**
# 1. **Team:** Team's name
# 2. **Tournament:** Number of played tournaments.
# 3. **Score:** Team’s score so far.
# 4. **PlayedGames:** Games played by the team so far.
# 5. **WonGames:** Games won by the team so far.
# 6. **DrawnGames:** Games drawn by the team so far.
# 7. **LostGames:** Games lost by the team so far.
# 8. **BasketScored:** Basket scored by the team so far.
# 9. **BasketGiven:** Basket scored against the team so far.
# 10. **TournamentChampion:** How many times the team was a champion of the tournaments so far.
# 11. **Runner-up:** How many times the team was a runners-up of the tournaments so far.
# 12. **TeamLaunch:** Year the team was launched on professional basketball.
# 13. **HighestPositionHeld:** Highest position held by the team amongst all the tournaments played.
# - **PROJECT OBJECTIVE:** Company’s management wants to invest on proposals on managing some of the best teams in the league. The analytics department has been assigned with a task of creating a report on the performance shown by the teams. Some of the older teams are already in contract with competitors. Hence Company X wants to understand which teams they can approach which will be a deal win for them.

# %% [markdown]
# ### STEPS AND TASK

# %% [markdown]
# > 1. Read the data set, clean the data and prepare final dataset to be used for analysis.

# %% [markdown]
# ### Ans:

# %%
df_sports = pd.read_csv("Basketball.csv")
df_sports.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
df_sports.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  -         -    2009-10
# 57           37          57                  -         -    1956-57
# 58           51          85                  -         -    1951~52
# 59           34          65                  -         -    1955-56
# 60            -           -                  -         -    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %%
df_sports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
df_sports.describe(include='all').T
# Out:
#                     count unique     top freq      mean        std  min  25%  \
# Team                   61     61  Team 1    1       NaN        NaN  NaN  NaN
# Tournament           61.0    NaN     NaN  NaN      24.0  26.827225  1.0  4.0
# Score                  61     61    4385    1       NaN        NaN  NaN  NaN
# PlayedGames            61     53    2762    3       NaN        NaN  NaN  NaN
# WonGames               61     59       7    2       NaN        NaN  NaN  NaN
# DrawnGames             61     57      14    2       NaN        NaN  NaN  NaN
# LostGames              61     56      37    3       NaN        NaN  NaN  NaN
# BasketScored           61     60      70    2       NaN        NaN  NaN  NaN
# BasketGiven            61     61    3140    1       NaN        NaN  NaN  NaN
# TournamentChampion     61      8       -   52       NaN        NaN  NaN  NaN
# Runner-up              61     10       -   48       NaN        NaN  NaN  NaN
# ...

# %%
df_sports['TeamLaunch'].unique()
# Out:
# array(['1929', '1931to32', '1934-35', '1939-40', '1932-33', '1941to42',
#        '1948-49', '1944_45', '1935-36', '1949_50', '1933to34', '1960-61',
#        '1951-52', '1998-99', '1941-42', '1977-78', '1959-60', '2004to05',
#        '1961-62', '1940-41', '1930-31', '1963-64', '1974-75', '1943-44',
#        '1987-88', '1991_92', '2007-08', '1962-63', '1994-95', '1978-79',
#        '1971-72', '1999to00', '2014-15', '1990-91', '1947-48', '1996-97',
#        '1995-96', '1945-46', '1953-54', '1979-80', '1950-51', '2016_17',
#        '2009-10', '1956-57', '1951~52', '1955-56', '2017~18'],
#       dtype=object)

# %%
# Taking only first 4 letters to make it numeric column
df_sports['TeamLaunch'] = df_sports['TeamLaunch'].apply(lambda x: x[:4])
df_sports['TeamLaunch'].unique()
# Out:
# array(['1929', '1931', '1934', '1939', '1932', '1941', '1948', '1944',
#        '1935', '1949', '1933', '1960', '1951', '1998', '1977', '1959',
#        '2004', '1961', '1940', '1930', '1963', '1974', '1943', '1987',
#        '1991', '2007', '1962', '1994', '1978', '1971', '1999', '2014',
#        '1990', '1947', '1996', '1995', '1945', '1953', '1979', '1950',
#        '2016', '2009', '1956', '1955', '2017'], dtype=object)

# %%
df_sports[df_sports['Score'] == '-']
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 60            -           -                  -         -       2017
#
#     HighestPositionHeld
# 60                    9

# %%
# drop this row as most of the data not available
df_sports.drop(60, inplace=True)
df_sports
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
# replace the hyphen with 0
df_sports['TournamentChampion'], df_sports['Runner-up'] = df_sports['TournamentChampion'].replace({'-':0}), df_sports['Runner-up'].replace({'-':0})
df_sports
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
# change the data type of numeric columns treating as object
non_numeric_cols = ['Score', 'PlayedGames', 'WonGames', 'DrawnGames', 'LostGames', 'BasketScored', 'BasketGiven', 'TournamentChampion', 'Runner-up', 'TeamLaunch']
df_sports[non_numeric_cols] = df_sports[non_numeric_cols].apply(pd.to_numeric)
df_sports.dtypes
# Out:
# Team                   object
# Tournament              int64
# Score                   int64
# PlayedGames             int64
# WonGames                int64
# DrawnGames              int64
# LostGames               int64
# BasketScored            int64
# BasketGiven             int64
# TournamentChampion      int64
# Runner-up               int64
# TeamLaunch              int64
# HighestPositionHeld     int64
# dtype: object

# %%
# Check if any duplicate data exists
df_sports.duplicated().sum()
# Out:
# 0

# %%
df_sports.describe(include='all').T
# Out:
#                     count unique     top freq         mean          std  \
# Team                   60     60  Team 1    1          NaN          NaN
# Tournament           60.0    NaN     NaN  NaN    24.383333     26.88462
# Score                60.0    NaN     NaN  NaN       916.45  1138.342899
# PlayedGames          60.0    NaN     NaN  NaN        810.1   877.465393
# WonGames             60.0    NaN     NaN  NaN   309.033333   408.481395
# DrawnGames           60.0    NaN     NaN  NaN   192.083333   201.985508
# LostGames            60.0    NaN     NaN  NaN   308.816667   294.508639
# BasketScored         60.0    NaN     NaN  NaN      1159.35  1512.063948
# BasketGiven          60.0    NaN     NaN  NaN  1159.233333  1163.946914
# TournamentChampion   60.0    NaN     NaN  NaN         1.45      5.51554
# Runner-up            60.0    NaN     NaN  NaN     1.433333     4.574679
# TeamLaunch           60.0    NaN     NaN  NaN      1957.95    26.646732
# ...

# %%
# We can use this dataframe as the final dataset for analytics
df_sports
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 5    Team 6          73   2819         2408       990         531        887
# 6    Team 7          82   2792         2626       948         608       1070
# 7    Team 8          70   2573         2302       864         577        861
# 8    Team 9          58   2109         1986       698         522        766
# 9   Team 10          51   1884         1728       606         440        682
# 10  Team 11          45   1814         1530       563         392        575
# ...

# %% [markdown]
# > 2. Perform detailed statistical analysis and EDA using univariate, bi-variate and multivariate EDA techniques to get data driven insights on recommending which teams they can approach which will be a deal win for them. Also as a data and statistics expert you have to develop a detailed performance report using this data.
#
# (Hint: Use statistical techniques and visualisation techniques to come up with useful metrics and reporting. Find out the best performing team, oldest team, team with highest goals, team with lowest performance etc. and many more. These are just random examples. Please use your best analytical approach to build this report. You can mix match columns to create new ones which can be used for better analysis. Create your own features if required. Be highly experimental and analytical here to find hidden patterns. Use graphical interactive libraries to enable you to publish interactive plots in python.)

# %% [markdown]
# ### Ans:

# %%
# creating a histogram of Tournament
sns.histplot(data = df_sports, x = 'Tournament', kde = False);

# %%
# creating a boxplot of Tournament
sns.boxplot(data = df_sports, x = 'Tournament');

# %%
# creating a histogram of Score
sns.histplot(data = df_sports, x = 'Score', kde = False);

# %%
# creating a boxplot of Score
sns.boxplot(data = df_sports, x = 'Score');

# %%
# creating a histogram of PlayedGames
sns.histplot(data = df_sports, x = 'PlayedGames', kde = False);

# %%
# creating a boxplot of PlayedGames
sns.boxplot(data = df_sports, x = 'PlayedGames');

# %%
# creating a histogram of WonGames
sns.histplot(data = df_sports, x = 'WonGames', kde = False);

# %%
# creating a boxplot of WonGames
sns.boxplot(data = df_sports, x = 'WonGames');

# %%
# creating a histogram of LostGames
sns.histplot(data = df_sports, x = 'LostGames', kde = False);

# %%
# creating a boxplot of LostGames
sns.boxplot(data = df_sports, x = 'LostGames');

# %% [markdown]
# #### Let's try to visualise how these numerical variables are associated with each other

# %%
# Plotting pairplot
plt.figure(figsize=(30, 30))
sns.pairplot(df_sports, diag_kind="kde");

# %%
plt.figure(figsize=(15, 7))
corr = df_sports.corr(numeric_only=True)
sns.heatmap(corr, vmin = -1, vmax = 1, annot=True);

# %%
df_sports[df_sports['WonGames'] == df_sports['WonGames'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld
# 0                    1

# %%
df_sports[df_sports['Runner-up'] == df_sports['Runner-up'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 1  Team 2          86   4262         2762      1581         573        608
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 1          5900         3114                  25         25        1929
#
#    HighestPositionHeld
# 1                    1

# %%
df_sports[df_sports['TournamentChampion'] == df_sports['TournamentChampion'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld
# 0                    1

# %% [markdown]
# > 3. Please include any improvements or suggestions to the association management on quality, quantity, variety, velocity, veracity etc. on the data points collected by the association to perform a better data analysis in future. At-least 1 suggestion for each point.

# %% [markdown]
# # Part C

# %% [markdown]
# - **DOMAIN:** Startup ecosystem
# - **CONTEXT:** Company X is a EU online publisher focusing on the startups industry. The company specifically reports on the business related to technology news, analysis of emerging trends and profiling of new tech businesses and products. Their event i.e. Startup Battlefield is the world's pre-eminent startup competition. Startup Battlefield features 15-30 top early stage startups pitching top judges in front of a vast live audience, present in person and online.
# - **DATA DESCRIPTION:** CompanyX_EU.csv - Each row in the dataset is a Start-up company and the columns describe the company.
# - **DATA DICTIONARY:**
# 1. **Startup:** Name of the company
# 2. **Product:** Actual product
# 3. **Funding:** Funds raised by the company in USD
# 4. **Event:** The event the company participated in
# 5. **Result:** Described by Contestant, Finalist, Audience choice, Winner or Runner up
# 6. **OperatingState:** Current status of the company, Operating ,Closed, Acquired or IPO
#
#     * Dataset has been downloaded from the internet. All the credit for the dataset goes to the original creator of the data.
# - **PROJECT OBJECTIVE:** Analyse the data of the various companies from the given dataset and perform the tasks that are specified in the below steps. Draw insights from the various attributes that are present in the dataset, plot distributions, state hypotheses and draw conclusions from the dataset.

# %% [markdown]
# ### STEPS AND TASK

# %% [markdown]
# > 1. Read the CSV file.

# %% [markdown]
# ### Ans:

# %%
df_X_EU = pd.read_csv("CompanyX_EU.csv")
df_X_EU.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %%
df_X_EU.tail()
# Out:
#     Startup       Product Funding            Event           Result  \
# 657  Zivity    zivity.com     $8M        TC40 2007       Contestant
# 658  Zmorph  zmorph3d.com     $1M                -  Audience choice
# 659  Zocdoc    zocdoc.com   $223M        TC40 2007       Contestant
# 660    Zula   zulaapp.com   $3.4M  Disrupt SF 2013  Audience choice
# 661  Zumper    zumper.com  $31.5M  Disrupt SF 2012         Finalist
#
#     OperatingState
# 657      Operating
# 658      Operating
# 659      Operating
# 660      Operating
# 661      Operating

# %%
df_X_EU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Startup         662 non-null    object
#  1   Product         656 non-null    object
#  2   Funding         448 non-null    object
#  3   Event           662 non-null    object
#  4   Result          662 non-null    object
#  5   OperatingState  662 non-null    object
# dtypes: object(6)
# memory usage: 31.2+ KB

# %%
df_X_EU.describe()
# Out:
#        Startup     Product Funding      Event      Result OperatingState
# count      662         656     448        662         662            662
# unique     662         656     240         26           5              4
# top     2600Hz  2600hz.com     $1M  TC50 2008  Contestant      Operating
# freq         1           1      17         52         488            465

# %% [markdown]
# > 2. Data Exploration:
# > - A. Check the datatypes of each attribute.

# %% [markdown]
# ### Ans:

# %%
df_X_EU.dtypes
# Out:
# Startup           object
# Product           object
# Funding           object
# Event             object
# Result            object
# OperatingState    object
# dtype: object

# %% [markdown]
# > - B. Check for null values in the attributes.

# %% [markdown]
# ### Ans:

# %%
df_X_EU.isnull().sum()
# Out:
# Startup             0
# Product             6
# Funding           214
# Event               0
# Result              0
# OperatingState      0
# dtype: int64

# %% [markdown]
# > 3. Data preprocessing & visualisation:
# > - A. Drop the null values.

# %% [markdown]
# ### Ans:

# %%
df1 = df_X_EU.dropna().copy()
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#           Startup          Product Funding                      Event  \
# 0            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 1      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 2            5to1         5to1.com  $19.3M                  TC50 2009
# 3    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 4      AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 441        Zivity       zivity.com     $8M                  TC40 2007
# 442        Zmorph     zmorph3d.com     $1M                          -
# 443        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 444          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 445        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState
# 0         Contestant         Closed
# 1    Audience choice      Operating
# ...

# %% [markdown]
# > - B. Convert the "Funding" features to a numerical value.
#
# (Execute below code)
#
# df1.loc[:,'Funds_in_million'] = df1['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))

# %% [markdown]
# ### Ans:

# %%
df1.loc[:,'Funds_in_million'] = df1['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))
df1
# Out:
#           Startup          Product Funding                      Event  \
# 0            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 1      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 2            5to1         5to1.com  $19.3M                  TC50 2009
# 3    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 4      AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 441        Zivity       zivity.com     $8M                  TC40 2007
# 442        Zmorph     zmorph3d.com     $1M                          -
# 443        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 444          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 445        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState  Funds_in_million
# 0         Contestant         Closed              0.63
# ...

# %% [markdown]
# > - C. Plot box plot for funds in million.

# %% [markdown]
# ### Ans:

# %%
plt.boxplot(df1['Funds_in_million'])
plt.show()
sns.boxplot(data=df1,x=df1['Funds_in_million'],showfliers=False)
plt.show()

# %% [markdown]
# > - D. Check the number of outliers greater than the upper fence.

# %% [markdown]
# ### Ans:

# %%
# find the 25th percentile and 75th percentile
q1 = df1['Funds_in_million'].quantile(0.25)
q3 = df1['Funds_in_million'].quantile(0.75)

iqr = q3 - q1    # Inter Quantile Range (75% - 25%)

upper_fence = q3 + 1.5 * iqr    # Calculate the upper fence

upper_outliers = df1[df1['Funds_in_million'] > upper_fence]    # set the upper outliers data in a vadiable
# upper_outliers.shape[0]    # Number of rows in the outliers data
print("The number of outliers greater than the upper fence is", upper_outliers.shape[0])
# Out:
# The number of outliers greater than the upper fence is 60

# %% [markdown]
# > - E. Check frequency of the OperatingState features classes.

# %% [markdown]
# ### Ans:

# %%
df1['OperatingState'].value_counts()
# Out:
# Operating    319
# Acquired      66
# Closed        57
# Ipo            4
# Name: OperatingState, dtype: int64

# %% [markdown]
# > 4. Statistical Analysis:
# > -    A. Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?

# %% [markdown]
# ### Ans:

# %%
df_fund_raised = df1.groupby(['OperatingState'])['Funds_in_million'].sum().reset_index()
df_fund_raised
# Out:
#   OperatingState  Funds_in_million
# 0       Acquired          872.0510
# 1         Closed          185.7157
# 2            Ipo          551.1000
# 3      Operating         6080.8372

# %% [markdown]
# It is clear that there is a significant difference between Funds raised by companies that are still operating vs companies that closed down

# %% [markdown]
# > - B. Write the null hypothesis and alternative hypothesis.

# %% [markdown]
# ### Ans:

# %%
df_fund_raised['percent'] = (df_fund_raised['Funds_in_million'] / df_fund_raised['Funds_in_million'].sum()) * 100
df_fund_raised
# Out:
#   OperatingState  Funds_in_million    percent
# 0       Acquired          872.0510  11.340502
# 1         Closed          185.7157   2.415122
# 2            Ipo          551.1000   7.166726
# 3      Operating         6080.8372  79.077651

# %% [markdown]
# $H_0 =$ Null hypothesis is :
# Funds raised by companies that operating is >= 75%
#
# $H_a =$ Alternative hypothesis is :
# Funds raised by companies that operating < 75%

# %% [markdown]
# > - C. Test for significance and conclusion

# %% [markdown]
# > - D. Make a copy of the original data frame.

# %% [markdown]
# ### Ans:

# %%
CompanyX_EU = df_X_EU.copy()
CompanyX_EU
# Out:
#              Startup             Product Funding             Event  \
# 0             2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1               3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2        3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3         3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4    42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
# ..               ...                 ...     ...               ...
# 657           Zivity          zivity.com     $8M         TC40 2007
# 658           Zmorph        zmorph3d.com     $1M                 -
# 659           Zocdoc          zocdoc.com   $223M         TC40 2007
# 660             Zula         zulaapp.com   $3.4M   Disrupt SF 2013
# 661           Zumper          zumper.com  $31.5M   Disrupt SF 2012
#
#               Result OperatingState
# 0         Contestant      Operating
# 1         Contestant         Closed
# 2         Contestant      Operating
# ...

# %% [markdown]
# > - E. Check frequency distribution of Result variables.

# %% [markdown]
# ### Ans:

# %%
df1['Result'].value_counts(normalize=True)
# Out:
# Contestant         0.699552
# Finalist           0.145740
# Audience choice    0.056054
# Winner             0.056054
# Runner up          0.042601
# Name: Result, dtype: float64

# %% [markdown]
# > - F. Calculate percentage of winners that are still operating and percentage of contestants that are still operating

# %% [markdown]
# ### Ans:

# %%
# Assigning the data to another variable for the companies that are operating
df_operating = df1.loc[df1['OperatingState'] == 'Operating'].reset_index()
df_operating
# Out:
#      index       Startup          Product Funding                      Event  \
# 0        1    3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 1        3  8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 2        4    AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# 3        6      Agrilyst     agrilyst.com     $1M            Disrupt SF 2015
# 4        7         Aiden         aiden.ai   $750K        Disrupt London 2016
# ..     ...           ...              ...     ...                        ...
# 314    441        Zivity       zivity.com     $8M                  TC40 2007
# 315    442        Zmorph     zmorph3d.com     $1M                          -
# 316    443        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 317    444          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 318    445        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
# ...

# %%
df_operating['Result'].value_counts(normalize=True)
# Out:
# Contestant         0.670846
# Finalist           0.144201
# Audience choice    0.072100
# Winner             0.056426
# Runner up          0.056426
# Name: Result, dtype: float64

# %% [markdown]
# Percentage of winners that are still operating is 5.6426% and percentage of contestants that are still operating is 76.0846%

# %% [markdown]
# > - G. Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:

# %% [markdown]
# > - H. Test for significance and conclusion

# %% [markdown]
# > - I. Select only the Event that has ‘disrupt’ keyword from 2013 onwards.

# %% [markdown]
# ### Ans:

# %%
# Checking the unique values in the Event column
df1['Event'].unique()
# Out:
# array(['Disrupt NYC 2013', 'Disrupt NY 2016', 'TC50 2009',
#        'Disrupt Beijing 2011', 'Hardware Battlefield 2014', 'TC50 2008',
#        'Disrupt SF 2015', 'Disrupt London 2016', 'Disrupt NYC 2014',
#        'Disrupt SF 2012', 'Disrupt SF 2011', 'TC40 2007',
#        'Disrupt NYC 2010', 'Disrupt NYC 2012', 'Disrupt EU 2013',
#        'Disrupt NYC 2011', 'Disrupt SF 2010', 'Disrupt SF 2014',
#        'Disrupt SF 2013', 'Disrupt NY 2015', 'Disrupt SF 2016', '-',
#        'Hardware Battlefield 2015', 'Hardware Battlefield 2016',
#        'Disrupt London 2015', 'Disrupt EU 2014'], dtype=object)

# %%
# replace the value - with nan
df1['Event'] = df1['Event'].replace(['-'],np.nan)
df1['Event'].value_counts(dropna=False)
# Out:
# TC50 2008                    31
# TC40 2007                    30
# TC50 2009                    26
# Disrupt SF 2011              24
# Disrupt NYC 2013             22
# Disrupt SF 2013              22
# Disrupt NY 2015              21
# Disrupt NYC 2012             21
# Disrupt SF 2012              20
# Disrupt SF 2014              19
# Disrupt NYC 2011             19
# Disrupt SF 2015              19
# Disrupt SF 2010              19
# Disrupt SF 2016              17
# Disrupt NYC 2014             16
# Disrupt NY 2016              16
# Disrupt NYC 2010             15
# Hardware Battlefield 2014    13
# Hardware Battlefield 2016    12
# Disrupt London 2015          12
# Disrupt London 2016          10
# Hardware Battlefield 2015    10
# Disrupt EU 2014              10
# Disrupt EU 2013               9
# Disrupt Beijing 2011          7
# NaN                           6
# Name: Event, dtype: int64

# %%
# assigning the data to another variable after droping the nan values
df2 = df1.dropna().copy()
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#           Startup          Product  Funding                      Event  \
# 0            3DLT         3dlt.com    $630K           Disrupt NYC 2013
# 1      3Dprintler   3dprintler.com      $1M            Disrupt NY 2016
# 2            5to1         5to1.com   $19.3M                  TC50 2009
# 3    8 Securities  8securities.com     $29M       Disrupt Beijing 2011
# 4      AdhereTech   adheretech.com    $1.8M  Hardware Battlefield 2014
# ..            ...              ...      ...                        ...
# 435      Zenefits     zenefits.com  $583.6M           Disrupt NYC 2013
# 436        Zivity       zivity.com      $8M                  TC40 2007
# 437        Zocdoc       zocdoc.com    $223M                  TC40 2007
# 438          Zula      zulaapp.com    $3.4M            Disrupt SF 2013
# 439        Zumper       zumper.com   $31.5M            Disrupt SF 2012
#
#               Result OperatingState  Funds_in_million
# 0         Contestant         Closed              0.63
# ...

# %%
# checking if the last 4 letters greater than or equal to 2013 and first 7 letters contains the keyword 'Disrupt'
df2.loc[:,'Disrupted Events 2013 onwards'] = df2['Event'].apply(lambda x: True if int(x[-4:]) > 2013 and x[:7] == 'Disrupt' else False)
df3 = df2.loc[df2['Disrupted Events 2013 onwards']]
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#         Startup         Product Funding                Event           Result  \
# 0    3Dprintler  3dprintler.com     $1M      Disrupt NY 2016  Audience choice
# 1      Agrilyst    agrilyst.com     $1M      Disrupt SF 2015           Winner
# 2         Aiden        aiden.ai   $750K  Disrupt London 2016       Contestant
# 3       Aircall      aircall.io  $11.6M      Disrupt SF 2015       Contestant
# 4       AirHelp     airhelp.com  $12.2M     Disrupt NYC 2014       Contestant
# ..          ...             ...     ...                  ...              ...
# 135      Wellth   wellthapp.com   $2.5M      Disrupt NY 2015       Contestant
# 136     Wellthy     wellthy.com     $2M      Disrupt SF 2015       Contestant
# 137   Welltwigs   welltwigs.com    $50K      Disrupt NY 2015       Contestant
# 138       Xendo       xendo.com    $28K      Disrupt SF 2014       Contestant
# 139  YayPay Inc      yaypay.com   $900K  Disrupt London 2015       Contestant
#
# ...

# %%
df3.describe(include='all')
# Out:
#            Startup         Product Funding            Event      Result  \
# count          140             140     140              140         140
# unique         140             140      89                9           5
# top     3Dprintler  3dprintler.com     $1M  Disrupt NY 2015  Contestant
# freq             1               1       9               21          96
# mean           NaN             NaN     NaN              NaN         NaN
# std            NaN             NaN     NaN              NaN         NaN
# min            NaN             NaN     NaN              NaN         NaN
# 25%            NaN             NaN     NaN              NaN         NaN
# 50%            NaN             NaN     NaN              NaN         NaN
# 75%            NaN             NaN     NaN              NaN         NaN
# max            NaN             NaN     NaN              NaN         NaN
#
#        OperatingState  Funds_in_million Disrupted Events 2013 onwards
# ...
